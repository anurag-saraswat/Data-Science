# %% [markdown]
# # Implementing a handwritten digit classifier using a neural network

# %% [markdown]
# ## Data Preparation

# %%
# importing libraries
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Loading Data Set
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
#Creating Flipped Data Set

x_train_flipped = 255- x_train
x_test_flipped = 255 - x_test

# %%
#Creating Mixed of Flipped and corresponding orignal image

a =  x_train[:int(x_train.shape[0]*0.5)]
b =  x_train_flipped[:int(x_train_flipped.shape[0]*0.5)]
x_train_mix = np.append(a,b,axis=0)

a =  x_test[:int(x_test.shape[0]*0.5)]
b =  x_test_flipped[:int(x_test_flipped.shape[0]*0.5)]
x_test_mix = np.append(a,b,axis=0)

y_train_mix = np.append(y_train[:int(y_train.shape[0]*0.5)],y_train[:int(y_train.shape[0]*0.5)],axis=0)
y_test_mix = np.append(y_test[:int(y_test.shape[0]*0.5)],y_test[:int(y_test.shape[0]*0.5)],axis=0)

# %% [markdown]
# ### Data Visualisation

# %%
# Visualising 10 random sample from training data
indexes = np.random.randint(0, x_train.shape[0], size=10)
images = x_train[indexes]

# plot the 10 mnist digits
plt.figure(figsize=(4, 4))
for i in range(len(indexes)):
    plt.subplot(2, 5, i + 1)
    image = images[i]
    plt.imshow(image, cmap='gray')
    plt.axis('off')

plt.show()
plt.close('all')

# %%
# Visualising 10 random sample from flipped training data
indexes = np.random.randint(0, x_train_flipped.shape[0], size=10)
images = x_train_flipped[indexes]

# plot the 10 mnist digits
plt.figure(figsize=(4, 4))
for i in range(len(indexes)):
    plt.subplot(2, 5, i + 1)
    image = images[i]
    plt.imshow(image, cmap='gray')
    plt.axis('off')

plt.show()
plt.close('all')

# %% [markdown]
# ### Resize and Normalizing Data

# %%
image_size = x_train.shape[1]
input_size = image_size **2
# resize and normalize
x_train = np.reshape(x_train, [-1, input_size])
x_train = x_train.astype('float32') / 255
x_test = np.reshape(x_test, [-1, input_size])
x_test = x_test.astype('float32') / 255

x_train_flipped = np.reshape(x_train_flipped, [-1, input_size])
x_train_flipped = x_train_flipped.astype('float32') / 255
x_test_flipped = np.reshape(x_test_flipped, [-1, input_size])
x_test_flipped = x_test_flipped.astype('float32') / 255


x_train_mix = np.reshape(x_train_mix, [-1, input_size])
x_train_mix = x_train_mix.astype('float32') / 255
x_test_mix = np.reshape(x_test_mix, [-1, input_size])
x_test_mix = x_test_mix.astype('float32') / 255

# %% [markdown]
# ## Designing Model Architecture using keras

# %%
#Importing Keras layers 

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.utils import to_categorical, plot_model
from keras.callbacks import History

# %%
# compute the number of labels
num_labels = len(np.unique(y_train))

# %%
# convert to one-hot vector
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

y_train_mix = to_categorical(y_train_mix)
y_test_mix = to_categorical(y_test_mix)

# %%
# model is a 3-layer MLP with ReLU and dropout after each layer
#Both the first and second MLP layers are identical in nature with 256 units each, followed by relu activation and dropout.

# setting network parameters
hidden_units = 256
dropout = 0.45


model = Sequential()
model.add(Dense(hidden_units, input_dim=input_size))
model.add(Activation('relu'))
model.add(Dropout(dropout))
model.add(Dense(hidden_units))
model.add(Activation('relu'))
model.add(Dropout(dropout))
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
#Compilation of model
#Using categorical_crossentropy as the loss function

model.compile(loss='categorical_crossentropy', optimizer='SGD',metrics=['accuracy'])

# %% [markdown]
# ## Model Fitting

# %% [markdown]
# ### For Batch Size 256

# %%
#Setting Batch Size
batch_size = 256

history = History()
model.fit(x_train, y_train, epochs=20, batch_size=batch_size ,callbacks=[history])

loss, acc = model.evaluate(x_test, y_test, batch_size=batch_size)
print("\nTest accuracy with batch size 256: %.1f%%" % (100.0 * acc))

loss_256 = history.history['loss']
# Out:
# Epoch 1/20
# 235/235 [==============================] - 2s 8ms/step - loss: 1.9069 - accuracy: 0.3751
# Epoch 2/20
# 235/235 [==============================] - 2s 8ms/step - loss: 1.2039 - accuracy: 0.6342
# Epoch 3/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.8850 - accuracy: 0.7279
# Epoch 4/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.7452 - accuracy: 0.7681
# Epoch 5/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.6572 - accuracy: 0.7972
# Epoch 6/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.6005 - accuracy: 0.8165
# Epoch 7/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5579 - accuracy: 0.8314
# Epoch 8/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5294 - accuracy: 0.8414
# Epoch 9/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4994 - accuracy: 0.8496
# Epoch 10/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4774 - accuracy: 0.8579
# Epoch 11/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4592 - accuracy: 0.8629
# Epoch 12/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4410 - accuracy: 0.8680
# Epoch 13/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4253 - accuracy: 0.8739
# Epoch 14/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4098 - accuracy: 0.8782
# Epoch 15/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3996 - accuracy: 0.8813
# Epoch 16/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3881 - accuracy: 0.8845
# Epoch 17/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3809 - accuracy: 0.8871
# Epoch 18/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3713 - accuracy: 0.8906
# Epoch 19/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3625 - accuracy: 0.8917
# Epoch 20/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3561 - accuracy: 0.8942
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2348 - accuracy: 0.9302
#
# Test accuracy with batch size 256: 93.0%

# %%
#Setting Batch Size for flipped image
batch_size = 256

history = History()
model.fit(x_train_flipped, y_train, epochs=20, batch_size=batch_size ,callbacks=[history])

loss, acc = model.evaluate(x_test_flipped, y_test, batch_size=batch_size)
print("\nTest accuracy with batch size 256: %.1f%%" % (100.0 * acc))

loss_256_flipped = history.history['loss']
# Out:
# Epoch 1/20
# 235/235 [==============================] - 2s 7ms/step - loss: 2.3240 - accuracy: 0.1667
# Epoch 2/20
# 235/235 [==============================] - 2s 6ms/step - loss: 1.8810 - accuracy: 0.3369
# Epoch 3/20
# 235/235 [==============================] - 2s 7ms/step - loss: 1.5076 - accuracy: 0.4773
# Epoch 4/20
# 235/235 [==============================] - 2s 7ms/step - loss: 1.2521 - accuracy: 0.5716
# Epoch 5/20
# 235/235 [==============================] - 2s 7ms/step - loss: 1.1070 - accuracy: 0.6216
# Epoch 6/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.9958 - accuracy: 0.6641
# Epoch 7/20
# 235/235 [==============================] - 2s 6ms/step - loss: 0.9233 - accuracy: 0.6918
# Epoch 8/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.8635 - accuracy: 0.7159
# Epoch 9/20
# 235/235 [==============================] - 2s 6ms/step - loss: 0.8073 - accuracy: 0.7337
# Epoch 10/20
# 235/235 [==============================] - 2s 6ms/step - loss: 0.7649 - accuracy: 0.7513
# Epoch 11/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.7317 - accuracy: 0.7642
# Epoch 12/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.7019 - accuracy: 0.7738
# Epoch 13/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.6749 - accuracy: 0.7843
# Epoch 14/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.6483 - accuracy: 0.7941
# Epoch 15/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.6307 - accuracy: 0.8007
# Epoch 16/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.6137 - accuracy: 0.8070
# Epoch 17/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5976 - accuracy: 0.8137
# Epoch 18/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5750 - accuracy: 0.8192
# Epoch 19/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5598 - accuracy: 0.8246
# Epoch 20/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5456 - accuracy: 0.8321
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2968 - accuracy: 0.9205
#
# Test accuracy with batch size 256: 92.0%

# %%
#Setting Batch Size for mix sample
batch_size = 256

history = History()
model.fit(x_train_mix, y_train_mix, epochs=20, batch_size=batch_size ,callbacks=[history])

loss, acc = model.evaluate(x_test_mix, y_test_mix, batch_size=batch_size)
print("\nTest accuracy with batch size 256: %.1f%%" % (100.0 * acc))

loss_256_mix = history.history['loss']
# Out:
# Epoch 1/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.6014 - accuracy: 0.8233
# Epoch 2/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4840 - accuracy: 0.8535
# Epoch 3/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4659 - accuracy: 0.8608
# Epoch 4/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4607 - accuracy: 0.8604
# Epoch 5/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4561 - accuracy: 0.8652
# Epoch 6/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4495 - accuracy: 0.8647
# Epoch 7/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4423 - accuracy: 0.8672
# Epoch 8/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4385 - accuracy: 0.8690
# Epoch 9/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4319 - accuracy: 0.8716
# Epoch 10/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4297 - accuracy: 0.8735
# Epoch 11/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4222 - accuracy: 0.8745
# Epoch 12/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4176 - accuracy: 0.8760
# Epoch 13/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4211 - accuracy: 0.8757
# Epoch 14/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4085 - accuracy: 0.8789
# Epoch 15/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4052 - accuracy: 0.8808
# Epoch 16/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4024 - accuracy: 0.8813
# Epoch 17/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3987 - accuracy: 0.8821
# Epoch 18/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3956 - accuracy: 0.8836
# Epoch 19/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3933 - accuracy: 0.8849
# Epoch 20/20
# 235/235 [==============================] - 2s 7ms/step - loss: 0.3905 - accuracy: 0.8837
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2845 - accuracy: 0.9167
#
# Test accuracy with batch size 256: 91.7%

# %% [markdown]
# ### For Batch Size 128

# %%
#Setting Batch Size
batch_size = 128

history = History()
model.fit(x_train, y_train, epochs=20, batch_size=batch_size ,callbacks=[history])

loss, acc = model.evaluate(x_test, y_test, batch_size=batch_size)
print("\nTest accuracy with batch size 128: %.1f%%" % (100.0 * acc))

loss_128 = history.history['loss']
# Out:
# Epoch 1/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2777 - accuracy: 0.9162
# Epoch 2/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2691 - accuracy: 0.9205
# Epoch 3/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2588 - accuracy: 0.9225
# Epoch 4/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2498 - accuracy: 0.9254
# Epoch 5/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2447 - accuracy: 0.9278
# Epoch 6/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2348 - accuracy: 0.9298
# Epoch 7/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2309 - accuracy: 0.9318
# Epoch 8/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2221 - accuracy: 0.9347
# Epoch 9/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2214 - accuracy: 0.9344
# Epoch 10/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2128 - accuracy: 0.9370
# Epoch 11/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2100 - accuracy: 0.9367
# Epoch 12/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2071 - accuracy: 0.9385
# Epoch 13/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2040 - accuracy: 0.9393
# Epoch 14/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1995 - accuracy: 0.9413
# Epoch 15/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1960 - accuracy: 0.9425
# Epoch 16/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1962 - accuracy: 0.9414
# Epoch 17/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1924 - accuracy: 0.9427
# Epoch 18/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1870 - accuracy: 0.9452
# Epoch 19/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1842 - accuracy: 0.9452
# Epoch 20/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1813 - accuracy: 0.9457
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1137 - accuracy: 0.9640
#
# Test accuracy with batch size 128: 96.4%

# %%
#Setting Batch Size for flipped image
batch_size = 128

history = History()
model.fit(x_train_flipped, y_train, epochs=20, batch_size=batch_size ,callbacks=[history])

loss, acc = model.evaluate(x_test_flipped, y_test, batch_size=batch_size)
print("\nTest accuracy with batch size 128: %.1f%%" % (100.0 * acc))

loss_128_flipped = history.history['loss']
# Out:
# Epoch 1/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.5410 - accuracy: 0.8369
# Epoch 2/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.4843 - accuracy: 0.8546
# Epoch 3/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.4495 - accuracy: 0.8640
# Epoch 4/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.4268 - accuracy: 0.8715
# Epoch 5/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.4097 - accuracy: 0.8771
# Epoch 6/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3898 - accuracy: 0.8844
# Epoch 7/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3793 - accuracy: 0.8864
# Epoch 8/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3699 - accuracy: 0.8906
# Epoch 9/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3554 - accuracy: 0.8946
# Epoch 10/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3489 - accuracy: 0.8961
# Epoch 11/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3424 - accuracy: 0.8981
# Epoch 12/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3316 - accuracy: 0.9007
# Epoch 13/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3285 - accuracy: 0.9018
# Epoch 14/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3208 - accuracy: 0.9061
# Epoch 15/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3162 - accuracy: 0.9071
# Epoch 16/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3057 - accuracy: 0.9102
# Epoch 17/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2956 - accuracy: 0.9122
# Epoch 18/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2963 - accuracy: 0.9126
# Epoch 19/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2903 - accuracy: 0.9147
# Epoch 20/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2793 - accuracy: 0.9175
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1492 - accuracy: 0.9533
#
# Test accuracy with batch size 128: 95.3%

# %%
#Setting Batch Size for mix sample
batch_size = 128

history = History()
model.fit(x_train_mix, y_train_mix, epochs=20, batch_size=batch_size ,callbacks=[history])

loss, acc = model.evaluate(x_test_mix, y_test_mix, batch_size=batch_size)
print("\nTest accuracy with batch size 128: %.1f%%" % (100.0 * acc))

loss_128_mix = history.history['loss']
# Out:
# Epoch 1/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3775 - accuracy: 0.8970
# Epoch 2/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2854 - accuracy: 0.9164
# Epoch 3/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2708 - accuracy: 0.9211
# Epoch 4/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2619 - accuracy: 0.9218
# Epoch 5/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2561 - accuracy: 0.9246
# Epoch 6/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2519 - accuracy: 0.9255
# Epoch 7/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2514 - accuracy: 0.9279
# Epoch 8/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2448 - accuracy: 0.9278
# Epoch 9/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2458 - accuracy: 0.9276
# Epoch 10/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2390 - accuracy: 0.9295
# Epoch 11/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2378 - accuracy: 0.9308
# Epoch 12/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2360 - accuracy: 0.9305
# Epoch 13/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2393 - accuracy: 0.9306
# Epoch 14/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2330 - accuracy: 0.9315
# Epoch 15/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2286 - accuracy: 0.9320
# Epoch 16/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2287 - accuracy: 0.9338
# Epoch 17/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2283 - accuracy: 0.9331
# Epoch 18/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2244 - accuracy: 0.9344
# Epoch 19/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2246 - accuracy: 0.9339
# Epoch 20/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2240 - accuracy: 0.9349
# 79/79 [==============================] - 0s 2ms/step - loss: 0.1710 - accuracy: 0.9494
#
# Test accuracy with batch size 128: 94.9%

# %% [markdown]
# ### For Batch Size 64

# %%
#Setting Batch Size
batch_size = 64

history = History()
model.fit(x_train, y_train, epochs=20, batch_size=batch_size ,callbacks=[history])

loss, acc = model.evaluate(x_test, y_test, batch_size=batch_size)
print("\nTest accuracy with batch size 64: %.1f%%" % (100.0 * acc))

loss_64 = history.history['loss']
# Out:
# Epoch 1/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1743 - accuracy: 0.9480
# Epoch 2/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1656 - accuracy: 0.9507
# Epoch 3/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1544 - accuracy: 0.9533
# Epoch 4/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1534 - accuracy: 0.9540
# Epoch 5/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1498 - accuracy: 0.9562
# Epoch 6/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1467 - accuracy: 0.9563
# Epoch 7/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1400 - accuracy: 0.9581
# Epoch 8/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1375 - accuracy: 0.9584
# Epoch 9/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1336 - accuracy: 0.9603
# Epoch 10/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1293 - accuracy: 0.9621
# Epoch 11/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1304 - accuracy: 0.9613
# Epoch 12/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1263 - accuracy: 0.9619
# Epoch 13/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1254 - accuracy: 0.9624
# Epoch 14/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1264 - accuracy: 0.9621
# Epoch 15/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1211 - accuracy: 0.9637
# Epoch 16/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1197 - accuracy: 0.9641
# Epoch 17/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1171 - accuracy: 0.9638
# Epoch 18/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1147 - accuracy: 0.9656
# Epoch 19/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1115 - accuracy: 0.9666
# Epoch 20/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1121 - accuracy: 0.9665
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0762 - accuracy: 0.9768
#
# Test accuracy with batch size 64: 97.7%

# %%
#Setting Batch Size for flipped image
batch_size = 64

history = History()
model.fit(x_train_flipped, y_train, epochs=20, batch_size=batch_size ,callbacks=[history])

loss, acc = model.evaluate(x_test_flipped, y_test, batch_size=batch_size)
print("\nTest accuracy with batch size 64: %.1f%%" % (100.0 * acc))

loss_64_flipped = history.history['loss']
# Out:
# Epoch 1/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3673 - accuracy: 0.8908
# Epoch 2/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3123 - accuracy: 0.9070
# Epoch 3/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2871 - accuracy: 0.9151
# Epoch 4/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2721 - accuracy: 0.9186
# Epoch 5/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2620 - accuracy: 0.9220
# Epoch 6/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2482 - accuracy: 0.9262
# Epoch 7/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2432 - accuracy: 0.9279
# Epoch 8/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2355 - accuracy: 0.9301
# Epoch 9/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2288 - accuracy: 0.9324
# Epoch 10/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2231 - accuracy: 0.9333
# Epoch 11/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2192 - accuracy: 0.9350
# Epoch 12/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2164 - accuracy: 0.9357
# Epoch 13/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2077 - accuracy: 0.9380
# Epoch 14/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2057 - accuracy: 0.9388
# Epoch 15/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2059 - accuracy: 0.9372
# Epoch 16/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1982 - accuracy: 0.9411
# Epoch 17/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1990 - accuracy: 0.9407
# Epoch 18/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1973 - accuracy: 0.9409
# Epoch 19/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1933 - accuracy: 0.9420
# Epoch 20/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1903 - accuracy: 0.9431
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0991 - accuracy: 0.9712
#
# Test accuracy with batch size 64: 97.1%

# %%
#Setting Batch Size for mix sample
batch_size = 64

history = History()
model.fit(x_train_mix, y_train_mix, epochs=20, batch_size=batch_size ,callbacks=[history])

loss, acc = model.evaluate(x_test_mix, y_test_mix, batch_size=batch_size)
print("\nTest accuracy with batch size 64: %.1f%%" % (100.0 * acc))

loss_64_mix = history.history['loss']
# Out:
# Epoch 1/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2599 - accuracy: 0.9262
# Epoch 2/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1909 - accuracy: 0.9433
# Epoch 3/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1807 - accuracy: 0.9450
# Epoch 4/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1759 - accuracy: 0.9470
# Epoch 5/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1726 - accuracy: 0.9477
# Epoch 6/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1719 - accuracy: 0.9487
# Epoch 7/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1731 - accuracy: 0.9482
# Epoch 8/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1674 - accuracy: 0.9493
# Epoch 9/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1655 - accuracy: 0.9501
# Epoch 10/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1643 - accuracy: 0.9496
# Epoch 11/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1635 - accuracy: 0.9503
# Epoch 12/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1577 - accuracy: 0.9526
# Epoch 13/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1583 - accuracy: 0.9525
# Epoch 14/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1581 - accuracy: 0.9525
# Epoch 15/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1546 - accuracy: 0.9530
# Epoch 16/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1581 - accuracy: 0.9526
# Epoch 17/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1558 - accuracy: 0.9531
# Epoch 18/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1490 - accuracy: 0.9540
# Epoch 19/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1496 - accuracy: 0.9546
# Epoch 20/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1495 - accuracy: 0.9545
# 157/157 [==============================] - 0s 2ms/step - loss: 0.1316 - accuracy: 0.9615
#
# Test accuracy with batch size 64: 96.1%

# %% [markdown]
# ### For Batch Size 32

# %%
#Setting Batch Size
batch_size = 32

history = History()
model.fit(x_train, y_train, epochs=20, batch_size=batch_size ,callbacks=[history])

loss, acc = model.evaluate(x_test, y_test, batch_size=batch_size)
print("\nTest accuracy with batch size 32: %.1f%%" % (100.0 * acc))

loss_32 = history.history['loss']
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1240 - accuracy: 0.9619
# Epoch 2/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1146 - accuracy: 0.9650
# Epoch 3/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1083 - accuracy: 0.9675
# Epoch 4/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1038 - accuracy: 0.9681
# Epoch 5/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1036 - accuracy: 0.9685
# Epoch 6/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0983 - accuracy: 0.9700
# Epoch 7/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0968 - accuracy: 0.9697
# Epoch 8/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0954 - accuracy: 0.9708
# Epoch 9/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0925 - accuracy: 0.9719
# Epoch 10/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0903 - accuracy: 0.9719
# Epoch 11/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0893 - accuracy: 0.9725
# Epoch 12/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0864 - accuracy: 0.9734
# Epoch 13/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0848 - accuracy: 0.9739
# Epoch 14/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0826 - accuracy: 0.9742
# Epoch 15/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0795 - accuracy: 0.9753
# Epoch 16/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0829 - accuracy: 0.9741
# Epoch 17/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0777 - accuracy: 0.9759
# Epoch 18/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0774 - accuracy: 0.9758
# Epoch 19/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0759 - accuracy: 0.9768
# Epoch 20/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0742 - accuracy: 0.9766
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0613 - accuracy: 0.9811
#
# Test accuracy with batch size 32: 98.1%

# %%
#Setting Batch Size for flipped image
batch_size = 32

history = History()
model.fit(x_train_flipped, y_train, epochs=20, batch_size=batch_size ,callbacks=[history])

loss, acc = model.evaluate(x_test_flipped, y_test, batch_size=batch_size)
print("\nTest accuracy with batch size 32: %.1f%%" % (100.0 * acc))

loss_32_flipped = history.history['loss']
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3142 - accuracy: 0.9029
# Epoch 2/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2557 - accuracy: 0.9226
# Epoch 3/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2375 - accuracy: 0.9280
# Epoch 4/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2129 - accuracy: 0.9354
# Epoch 5/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2121 - accuracy: 0.9346
# Epoch 6/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1997 - accuracy: 0.9381
# Epoch 7/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1983 - accuracy: 0.9403
# Epoch 8/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1945 - accuracy: 0.9417
# Epoch 9/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1864 - accuracy: 0.9438
# Epoch 10/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1823 - accuracy: 0.9442
# Epoch 11/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1776 - accuracy: 0.9451
# Epoch 12/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1766 - accuracy: 0.9464
# Epoch 13/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1730 - accuracy: 0.9475
# Epoch 14/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1680 - accuracy: 0.9480
# Epoch 15/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1656 - accuracy: 0.9495
# Epoch 16/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1628 - accuracy: 0.9498
# Epoch 17/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1579 - accuracy: 0.9504
# Epoch 18/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1587 - accuracy: 0.9512
# Epoch 19/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1591 - accuracy: 0.9514
# Epoch 20/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1552 - accuracy: 0.9517
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0872 - accuracy: 0.9732
#
# Test accuracy with batch size 32: 97.3%

# %%
#Setting Batch Size for mix sample
batch_size = 32

history = History()
model.fit(x_train_mix, y_train_mix, epochs=20, batch_size=batch_size ,callbacks=[history])

loss, acc = model.evaluate(x_test_mix, y_test_mix, batch_size=batch_size)
print("\nTest accuracy with batch size 32: %.1f%%" % (100.0 * acc))

loss_32_mix = history.history['loss']
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2088 - accuracy: 0.9373
# Epoch 2/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1504 - accuracy: 0.9532
# Epoch 3/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1414 - accuracy: 0.9558
# Epoch 4/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1385 - accuracy: 0.9571
# Epoch 5/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1362 - accuracy: 0.9574
# Epoch 6/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1306 - accuracy: 0.9594
# Epoch 7/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1315 - accuracy: 0.9591
# Epoch 8/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1272 - accuracy: 0.9593
# Epoch 9/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1302 - accuracy: 0.9586
# Epoch 10/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1260 - accuracy: 0.9610
# Epoch 11/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1233 - accuracy: 0.9611
# Epoch 12/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1268 - accuracy: 0.9597
# Epoch 13/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1231 - accuracy: 0.9607
# Epoch 14/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1213 - accuracy: 0.9619
# Epoch 15/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1223 - accuracy: 0.9624
# Epoch 16/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1198 - accuracy: 0.9624
# Epoch 17/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1186 - accuracy: 0.9616
# Epoch 18/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1179 - accuracy: 0.9635
# Epoch 19/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1162 - accuracy: 0.9631
# Epoch 20/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1169 - accuracy: 0.9635
# 313/313 [==============================] - 0s 2ms/step - loss: 0.1076 - accuracy: 0.9658
#
# Test accuracy with batch size 32: 96.6%

# %% [markdown]
# ### Comparison

# %%
plt.style.use("seaborn")
plt.xlabel("Epoch")
plt.ylabel("Error")
plt.title("Comparison of reduction in Error(In Orignal Sample)")

x = [i for i in range(1,21)]
plt.xticks(np.arange(min(x), max(x)+1, 1.0))

plt.plot(x,loss_32,label="Batch Size 32")
plt.plot(x,loss_64,label="Batch Size 64")
plt.plot(x,loss_128,label="Batch Size 128")
plt.plot(x,loss_256,label="Batch Size 256")

plt.legend()

plt.show()

# %%
# Comparision in case of Flipped images
plt.style.use("seaborn")
plt.xlabel("Epoch")
plt.ylabel("Error")
plt.title("Comparison of reduction in Error(In Flipped Sample)")

x = [i for i in range(1,21)]
plt.xticks(np.arange(min(x), max(x)+1, 1.0))

plt.plot(x,loss_32_flipped,label="Batch Size 32")
plt.plot(x,loss_64_flipped,label="Batch Size 64")
plt.plot(x,loss_128_flipped,label="Batch Size 128")
plt.plot(x,loss_256_flipped,label="Batch Size 256")

plt.legend()
plt.show()

# %%
plt.style.use("seaborn")
plt.xlabel("Epoch")
plt.ylabel("Error")
plt.title("Comparison of reduction in Error(In Mixed Sample)")

x = [i for i in range(1,21)]
plt.xticks(np.arange(min(x), max(x)+1, 1.0))

plt.plot(x,loss_32_mix,label="Batch Size 32")
plt.plot(x,loss_64_mix,label="Batch Size 64")
plt.plot(x,loss_128_mix,label="Batch Size 128")
plt.plot(x,loss_256_mix,label="Batch Size 256")

plt.legend()

plt.show()

# %%
plt.style.use("seaborn")
plt.xlabel("Epoch")
plt.ylabel("Error")
plt.title("Comparison of reduction in Error for batch size 32")

x = [i for i in range(1,21)]
plt.xticks(np.arange(min(x), max(x)+1, 1.0))

plt.plot(x,loss_32,label="Orignal")
plt.plot(x,loss_32_flipped,label="Flipped")
plt.plot(x,loss_32_mix,label="Mix")


plt.legend()

plt.show()

# %%
plt.style.use("seaborn")
plt.xlabel("Epoch")
plt.ylabel("Error")
plt.title("Comparison of reduction in Error for batch size 64")

x = [i for i in range(1,21)]
plt.xticks(np.arange(min(x), max(x)+1, 1.0))

plt.plot(x,loss_64,label="Orignal")
plt.plot(x,loss_64_flipped,label="Flipped")
plt.plot(x,loss_64_mix,label="Mix")


plt.legend()

plt.show()

# %%
plt.style.use("seaborn")
plt.xlabel("Epoch")
plt.ylabel("Error")
plt.title("Comparison of reduction in Error for batch size 128")

x = [i for i in range(1,21)]
plt.xticks(np.arange(min(x), max(x)+1, 1.0))

plt.plot(x,loss_128,label="Orignal")
plt.plot(x,loss_128_flipped,label="Flipped")
plt.plot(x,loss_128_mix,label="Mix")


plt.legend()

plt.show()

# %%
plt.style.use("seaborn")
plt.xlabel("Epoch")
plt.ylabel("Error")
plt.title("Comparison of reduction in Error for batch size 256")

x = [i for i in range(1,21)]
plt.xticks(np.arange(min(x), max(x)+1, 1.0))

plt.plot(x,loss_256,label="Orignal")
plt.plot(x,loss_256_flipped,label="Flipped")
plt.plot(x,loss_256_mix,label="Mix")



plt.legend()

plt.show()
